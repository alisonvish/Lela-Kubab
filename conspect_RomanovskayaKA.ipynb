# %%
(2 + 4) * 2
# Out:
# 12

# %% [markdown]
# Код выше написан на языке Python

# %%
pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/Lela-Kubab'

# %%
# !ls /
# Out:
# bin	 dev   lib32   mnt			 root  sys    var
# boot	 etc   lib64   NGC-DL-CONTAINER-LICENSE  run   tmp
# content  home  libx32  opt			 sbin  tools
# datalab  lib   media   proc			 srv   usr

# %% [markdown]
# # Настройка Git
# * настроим имя и email
# * получить токен от github

# %%
# !git config --global user.name "kr27904"
# !git config --global user.email "kr27904@mail.ru"

# %%
# !git remote set-url origin https://{token}@github.com/{username}/{repo}.git

# %%
# !git remote -v
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git push origin master
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %% [markdown]
# Перейдем в папку и подключимся к диску

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git clone https://github.com/alisonvish/Lela-Kubab.git
# Out:
# fatal: destination path 'Lela-Kubab' already exists and is not an empty directory.

# %%
# !mv conspect_RomanovskayaKA.ipynb Lela-Kubab/
# Out:
# mv: cannot stat 'conspect_RomanovskayaKA.ipynb': No such file or directory

# %%
cd /content/drive/MyDrive/Colab Notebooks/Lela-Kubab
# Out:
# /content/drive/MyDrive/Colab Notebooks/Lela-Kubab

# %% [markdown]
# # Математика Python
# * какие математические операции можно проводить с числами Python?
# * приведите примеры и найдите 3 отличия от классической математики
# * используйте ячейки кода и текста в Google Colab

# %%
2 + 2 * 2 - 2 / 2
# Out:
# 5.0

# %% [markdown]
# Как получить целую часть от деления:

# %%
40.5 / 5
# Out:
# 8.1

# %%
40.5//5
# Out:
# 8.0

# %% [markdown]
# Как возвести в степень:

# %%
5 ** 2

# %% [markdown]
# # Зона для коммитов

# %% [markdown]
# Передадим файл в репозиторий

# %%
# !git status
# Out:
# On branch master
# Your branch is ahead of 'origin/master' by 2 commits.
#   (use "git push" to publish your local commits)
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   conspect_RomanovskayaKA.ipynb

# %%
# !git add .

# %%
! git commit -m 'Добавил свой новый файл в репозитоий'
# Out:
# [master 295d9cc] Добавил свой новый файл в репозитоий
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite conspect_RomanovskayaKA.ipynb (96%)

# %%
token = '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'
username = 'alisonvish'
repo = 'Lela-Kubab'

# %%
# !git remote set-url origin https://{token}@github.com/{username}/{repo}.git

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/alisonvish/Lela-Kubab.git (fetch)
# origin	https://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@github.com/alisonvish/Lela-Kubab.git (push)

# %%
# !giy pull

# %%
# !git push origin master
# Out:
# To https://github.com/alisonvish/Lela-Kubab.git
#  ! [rejected]        master -> master (fetch first)
# error: failed to push some refs to 'https://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@github.com/alisonvish/Lela-Kubab.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.
